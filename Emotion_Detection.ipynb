# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense, BatchNormalization, Dropout
from keras.optimizers.legacy import Adam
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator , img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# #  Building our Model To train the data

# %%
# Working with pre trained model 
base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False

# Add new layers
x = Flatten()(base_model.output)
x = Dropout(0.2)(x)
x = BatchNormalization()(x)
x = Dense(units=128, activation='relu')(x)
x = Dropout(0.2)(x)
x = BatchNormalization()(x)
x = Dense(units=64, activation='relu')(x)
x = Dropout(0.2)(x)
x = BatchNormalization()(x)
x = Dense(units=7, activation='softmax')(x)

# creating our model.
model = Model(base_model.input, x)

# %%
optimizer = Adam(learning_rate=0.001)

# %%
model.compile(optimizer=optimizer, loss= categorical_crossentropy , metrics=['accuracy']  )

# %% [markdown]
# # Preparing our data using data generator

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255)

train_data = train_datagen.flow_from_directory(directory= "dataset/train", 
                                               target_size=(224,224), 
                                               batch_size=32)
train_data.class_indices
# Out:
# Found 28709 images belonging to 7 classes.
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "dataset/test", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # Visualizaing the data that is fed to train data gen

# %%
# to visualize the images in the traing data denerator 
t_img , label = train_data.next()

# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %% [markdown]
# # Having early stopping and model check point

# %%
# Define the callbacks
early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0.01, patience=5, verbose=1, mode='auto')
model_checkpoint = ModelCheckpoint(filepath="best_model.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='auto')

callbacks = [early_stopping, model_checkpoint]

# %%
# Train the model
hist = model.fit(train_data,
                           steps_per_epoch=len(train_data),
                           epochs=30,
                           validation_data=val_data,
                           validation_steps=len(val_data),
                           callbacks=callbacks)
# Out:
# Epoch 1/30
# 898/898 [==============================] - ETA: 0s - loss: 1.4393 - accuracy: 0.4728
# Epoch 1: val_accuracy improved from -inf to 0.55991, saving model to best_model.h5
# 898/898 [==============================] - 205s 227ms/step - loss: 1.4393 - accuracy: 0.4728 - val_loss: 1.1642 - val_accuracy: 0.5599
# Epoch 2/30
# 898/898 [==============================] - ETA: 0s - loss: 1.1980 - accuracy: 0.5536
# Epoch 2: val_accuracy improved from 0.55991 to 0.58470, saving model to best_model.h5
# 898/898 [==============================] - 196s 218ms/step - loss: 1.1980 - accuracy: 0.5536 - val_loss: 1.1120 - val_accuracy: 0.5847
# Epoch 3/30
# 898/898 [==============================] - ETA: 0s - loss: 1.1271 - accuracy: 0.5805
# Epoch 3: val_accuracy improved from 0.58470 to 0.59390, saving model to best_model.h5
# 898/898 [==============================] - 195s 217ms/step - loss: 1.1271 - accuracy: 0.5805 - val_loss: 1.0969 - val_accuracy: 0.5939
# Epoch 4/30
# 898/898 [==============================] - ETA: 0s - loss: 1.0812 - accuracy: 0.5947
# Epoch 4: val_accuracy improved from 0.59390 to 0.60031, saving model to best_model.h5
# 898/898 [==============================] - 195s 217ms/step - loss: 1.0812 - accuracy: 0.5947 - val_loss: 1.0803 - val_accuracy: 0.6003
# Epoch 5/30
# 898/898 [==============================] - ETA: 0s - loss: 1.0396 - accuracy: 0.6131
# Epoch 5: val_accuracy improved from 0.60031 to 0.60407, saving model to best_model.h5
# 898/898 [==============================] - 197s 219ms/step - loss: 1.0396 - accuracy: 0.6131 - val_loss: 1.0634 - val_accuracy: 0.6041
# Epoch 6/30
# 898/898 [==============================] - ETA: 0s - loss: 1.0054 - accuracy: 0.6283
# Epoch 6: val_accuracy did not improve from 0.60407
# 898/898 [==============================] - 198s 220ms/step - loss: 1.0054 - accuracy: 0.6283 - val_loss: 1.0786 - val_accuracy: 0.5995
# Epoch 7/30
# 898/898 [==============================] - ETA: 0s - loss: 0.9702 - accuracy: 0.6412
# Epoch 7: val_accuracy improved from 0.60407 to 0.61103, saving model to best_model.h5
# 898/898 [==============================] - 197s 219ms/step - loss: 0.9702 - accuracy: 0.6412 - val_loss: 1.0790 - val_accuracy: 0.6110
# Epoch 8/30
# 898/898 [==============================] - ETA: 0s - loss: 0.9426 - accuracy: 0.6533
# Epoch 8: val_accuracy did not improve from 0.61103
# 898/898 [==============================] - 196s 218ms/step - loss: 0.9426 - accuracy: 0.6533 - val_loss: 1.0806 - val_accuracy: 0.6095
# Epoch 9/30
# 898/898 [==============================] - ETA: 0s - loss: 0.9184 - accuracy: 0.6637
# Epoch 9: val_accuracy improved from 0.61103 to 0.61257, saving model to best_model.h5
# 898/898 [==============================] - 396s 441ms/step - loss: 0.9184 - accuracy: 0.6637 - val_loss: 1.0748 - val_accuracy: 0.6126
# Epoch 10/30
# 898/898 [==============================] - ETA: 0s - loss: 0.9002 - accuracy: 0.6679
# Epoch 10: val_accuracy improved from 0.61257 to 0.61368, saving model to best_model.h5
# 898/898 [==============================] - 197s 219ms/step - loss: 0.9002 - accuracy: 0.6679 - val_loss: 1.0688 - val_accuracy: 0.6137
# Epoch 11/30
# 898/898 [==============================] - ETA: 0s - loss: 0.8660 - accuracy: 0.6825
# Epoch 11: val_accuracy improved from 0.61368 to 0.61535, saving model to best_model.h5
# 898/898 [==============================] - 193s 214ms/step - loss: 0.8660 - accuracy: 0.6825 - val_loss: 1.0809 - val_accuracy: 0.6154
# Epoch 12/30
# 898/898 [==============================] - ETA: 0s - loss: 0.8480 - accuracy: 0.6900
# Epoch 12: val_accuracy did not improve from 0.61535
# 898/898 [==============================] - 194s 216ms/step - loss: 0.8480 - accuracy: 0.6900 - val_loss: 1.0827 - val_accuracy: 0.6145
# Epoch 12: early stopping

# %%
predictions = model.predict(val_data)
# Out:
# 225/225 [==============================] - 35s 155ms/step

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("best_model.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "dataset/test/angry/PrivateTest_1221822.jpg"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
# 1/1 [==============================] - 0s 19ms/step
#  the image is of angry
